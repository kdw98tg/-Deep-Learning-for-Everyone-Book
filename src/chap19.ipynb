# %% [markdown]
# # 19장 세상에 없는 얼굴 GAN, 오토인코더

# %% [markdown]
# ## 3. 적대적 신경망 실행하기

# %% [markdown]
# ### Gan 모델 만들기

# %% [markdown]
# - Gan은 딥러닝의 원리를 활용해 가상 이미지를 생성하는 알고리즘임
# - 경찰과 위조화폐범에 비유가됨
# - 위조화폐범이 갈수록 정교한 위조화폐를 만들어내려고 하고, 경찰은 위조화폐를 가려내기 위해서 더 정교한 위조화폐 분석 기술을 갖게된다는 아이디어에서 시작함
# - 여기서 위조화폐를 만드는 위조화폐범이 `생성자` 그걸 가려내는 경찰이 `판별자`에 해당됨
# - 이것을 진짜 같은 가짜를 만들기 위해 GAN 알고리즘 내부에서는 `적대적` 경합을 하고 있기 때문에 생성적 적대 신경망이라고 부름

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model

import numpy as np
import matplotlib.pyplot as plt

# 생성자 모델 생성
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))

# 판별자 모델 생성
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False

ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer = 'adam')
gan.summary()

# 신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):

  # MNIST 데이터를 불러옵니다.

  (X_train, _), (_, _) = mnist.load_data()  # 앞서 불러온 적 있는 MNIST를 다시 이용합니다. 단, 테스트 과정은 필요 없고 이미지만 사용할 것이기 때문에 X_train만 불러왔습니다.
  X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
  X_train = (X_train - 127.5) / 127.5  # 픽셀 값은 0에서 255 사이의 값입니다. 이전에 255로 나누어 줄때는 이를 0~1 사이의 값으로 바꾸었던 것인데, 여기서는 127.5를 빼준 뒤 127.5로 나누어 줌으로 인해 -1에서 1사이의 값으로 바뀌게 됩니다.
  # X_train.shape, Y_train.shape, X_test.shape, Y_test.shape

  true = np.ones((batch_size, 1))
  fake = np.zeros((batch_size, 1))

  for i in range(epoch):
          # 실제 데이터를 판별자에 입력하는 부분입니다.
          idx = np.random.randint(0, X_train.shape[0], batch_size)
          imgs = X_train[idx]
          d_loss_real = discriminator.train_on_batch(imgs, true)

          # 가상 이미지를 판별자에 입력하는 부분입니다.
          noise = np.random.normal(0, 1, (batch_size, 100))
          gen_imgs = generator.predict(noise)
          d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

          # 판별자와 생성자의 오차를 계산합니다.
          d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
          g_loss = gan.train_on_batch(noise, true)

          print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # 중간 과정을 이미지로 저장해 주는 부분
          if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)

              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5

              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("../data/gan_images/gan_mnist_%d.png" % i)

gan_train(2001, 32, 200)  # 2000번 반복되고, 배치 사이즈는 32,  200번마다 결과가 저장되게 하였습니다.
# Out:
# c:\Users\window11\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\Users\window11\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "functional_35"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_2 (Sequential)       │ (None, 28, 28, 1)      │       865,281 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_3 (Sequential)       │ (None, 1)              │       212,865 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,078,146 (4.11 MB)
#  Trainable params: 852,609 (3.25 MB)
#  Non-trainable params: 225,537 (881.00 KB)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# c:\Users\window11\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:82: UserWarning: The model does not have any trainable weights.
#   warnings.warn("The model does not have any trainable weights.")
# epoch:0  d_loss:0.6891  g_loss:0.7175
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1  d_loss:0.6960  g_loss:0.7099
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:2  d_loss:0.6986  g_loss:0.7035
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:3  d_loss:0.6978  g_loss:0.6950
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:4  d_loss:0.6981  g_loss:0.6882
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:5  d_loss:0.6994  g_loss:0.6849
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:6  d_loss:0.7014  g_loss:0.6802
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:7  d_loss:0.7020  g_loss:0.6774
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:8  d_loss:0.7028  g_loss:0.6736
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:9  d_loss:0.7037  g_loss:0.6705
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:10  d_loss:0.7042  g_loss:0.6681
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:11  d_loss:0.7052  g_loss:0.6646
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:12  d_loss:0.7063  g_loss:0.6612
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:13  d_loss:0.7073  g_loss:0.6584
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:14  d_loss:0.7086  g_loss:0.6561
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:15  d_loss:0.7094  g_loss:0.6538
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:16  d_loss:0.7100  g_loss:0.6518
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:17  d_loss:0.7113  g_loss:0.6503
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:18  d_loss:0.7122  g_loss:0.6476
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:19  d_loss:0.7130  g_loss:0.6457
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:20  d_loss:0.7142  g_loss:0.6439
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:21  d_loss:0.7152  g_loss:0.6418
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:22  d_loss:0.7159  g_loss:0.6399
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:23  d_loss:0.7170  g_loss:0.6384
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:24  d_loss:0.7179  g_loss:0.6367
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch:25  d_loss:0.7187  g_loss:0.6353
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch:26  d_loss:0.7194  g_loss:0.6336
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:27  d_loss:0.7203  g_loss:0.6321
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:28  d_loss:0.7210  g_loss:0.6307
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:29  d_loss:0.7220  g_loss:0.6294
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:30  d_loss:0.7225  g_loss:0.6280
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:31  d_loss:0.7232  g_loss:0.6262
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:32  d_loss:0.7238  g_loss:0.6246
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:33  d_loss:0.7247  g_loss:0.6233
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:34  d_loss:0.7253  g_loss:0.6219
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:35  d_loss:0.7261  g_loss:0.6205
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:36  d_loss:0.7269  g_loss:0.6189
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:37  d_loss:0.7276  g_loss:0.6176
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:38  d_loss:0.7284  g_loss:0.6161
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:39  d_loss:0.7290  g_loss:0.6150
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:40  d_loss:0.7297  g_loss:0.6138
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:41  d_loss:0.7305  g_loss:0.6125
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:42  d_loss:0.7312  g_loss:0.6114
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:43  d_loss:0.7317  g_loss:0.6103
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:44  d_loss:0.7324  g_loss:0.6091
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:45  d_loss:0.7331  g_loss:0.6079
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:46  d_loss:0.7338  g_loss:0.6067
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:47  d_loss:0.7344  g_loss:0.6055
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:48  d_loss:0.7349  g_loss:0.6043
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:49  d_loss:0.7355  g_loss:0.6030
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch:50  d_loss:0.7363  g_loss:0.6016
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch:51  d_loss:0.7369  g_loss:0.6005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:52  d_loss:0.7376  g_loss:0.5993
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:53  d_loss:0.7383  g_loss:0.5981
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:54  d_loss:0.7389  g_loss:0.5967
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:55  d_loss:0.7396  g_loss:0.5956
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:56  d_loss:0.7403  g_loss:0.5943
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:57  d_loss:0.7411  g_loss:0.5932
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:58  d_loss:0.7415  g_loss:0.5921
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:59  d_loss:0.7421  g_loss:0.5909
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:60  d_loss:0.7428  g_loss:0.5898
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:61  d_loss:0.7433  g_loss:0.5886
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:62  d_loss:0.7439  g_loss:0.5875
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:63  d_loss:0.7444  g_loss:0.5863
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:64  d_loss:0.7451  g_loss:0.5850
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:65  d_loss:0.7456  g_loss:0.5838
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:66  d_loss:0.7462  g_loss:0.5828
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:67  d_loss:0.7467  g_loss:0.5816
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:68  d_loss:0.7473  g_loss:0.5804
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:69  d_loss:0.7479  g_loss:0.5792
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:70  d_loss:0.7484  g_loss:0.5782
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:71  d_loss:0.7491  g_loss:0.5773
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:72  d_loss:0.7497  g_loss:0.5761
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:73  d_loss:0.7505  g_loss:0.5749
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:74  d_loss:0.7512  g_loss:0.5738
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:75  d_loss:0.7520  g_loss:0.5725
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:76  d_loss:0.7527  g_loss:0.5714
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:77  d_loss:0.7533  g_loss:0.5702
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:78  d_loss:0.7540  g_loss:0.5691
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:79  d_loss:0.7547  g_loss:0.5680
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:80  d_loss:0.7554  g_loss:0.5670
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:81  d_loss:0.7561  g_loss:0.5659
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:82  d_loss:0.7568  g_loss:0.5647
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch:83  d_loss:0.7575  g_loss:0.5636
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:84  d_loss:0.7582  g_loss:0.5624
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:85  d_loss:0.7589  g_loss:0.5612
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:86  d_loss:0.7595  g_loss:0.5601
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:87  d_loss:0.7603  g_loss:0.5590
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:88  d_loss:0.7610  g_loss:0.5580
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:89  d_loss:0.7617  g_loss:0.5570
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:90  d_loss:0.7624  g_loss:0.5559
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:91  d_loss:0.7630  g_loss:0.5548
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:92  d_loss:0.7637  g_loss:0.5537
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:93  d_loss:0.7644  g_loss:0.5526
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:94  d_loss:0.7651  g_loss:0.5516
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:95  d_loss:0.7658  g_loss:0.5505
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:96  d_loss:0.7665  g_loss:0.5494
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:97  d_loss:0.7671  g_loss:0.5483
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:98  d_loss:0.7678  g_loss:0.5472
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:99  d_loss:0.7684  g_loss:0.5461
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:100  d_loss:0.7692  g_loss:0.5450
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:101  d_loss:0.7699  g_loss:0.5440
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:102  d_loss:0.7707  g_loss:0.5428
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:103  d_loss:0.7715  g_loss:0.5417
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:104  d_loss:0.7723  g_loss:0.5406
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:105  d_loss:0.7730  g_loss:0.5396
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:106  d_loss:0.7739  g_loss:0.5386
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:107  d_loss:0.7746  g_loss:0.5374
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch:108  d_loss:0.7754  g_loss:0.5364
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:109  d_loss:0.7762  g_loss:0.5354
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:110  d_loss:0.7770  g_loss:0.5343
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:111  d_loss:0.7777  g_loss:0.5333
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:112  d_loss:0.7784  g_loss:0.5323
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:113  d_loss:0.7791  g_loss:0.5312
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:114  d_loss:0.7800  g_loss:0.5302
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch:115  d_loss:0.7808  g_loss:0.5292
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:116  d_loss:0.7817  g_loss:0.5281
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:117  d_loss:0.7825  g_loss:0.5271
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:118  d_loss:0.7833  g_loss:0.5260
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:119  d_loss:0.7842  g_loss:0.5250
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:120  d_loss:0.7849  g_loss:0.5239
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:121  d_loss:0.7857  g_loss:0.5230
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:122  d_loss:0.7865  g_loss:0.5219
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:123  d_loss:0.7873  g_loss:0.5209
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:124  d_loss:0.7882  g_loss:0.5200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:125  d_loss:0.7890  g_loss:0.5190
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:126  d_loss:0.7899  g_loss:0.5180
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:127  d_loss:0.7907  g_loss:0.5170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:128  d_loss:0.7916  g_loss:0.5160
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:129  d_loss:0.7923  g_loss:0.5150
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:130  d_loss:0.7932  g_loss:0.5140
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:131  d_loss:0.7940  g_loss:0.5130
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:132  d_loss:0.7948  g_loss:0.5121
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch:133  d_loss:0.7956  g_loss:0.5111
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:134  d_loss:0.7965  g_loss:0.5101
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:135  d_loss:0.7973  g_loss:0.5091
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:136  d_loss:0.7981  g_loss:0.5082
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:137  d_loss:0.7989  g_loss:0.5072
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:138  d_loss:0.7997  g_loss:0.5063
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:139  d_loss:0.8006  g_loss:0.5053
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:140  d_loss:0.8014  g_loss:0.5043
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:141  d_loss:0.8021  g_loss:0.5034
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:142  d_loss:0.8030  g_loss:0.5025
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:143  d_loss:0.8039  g_loss:0.5015
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:144  d_loss:0.8047  g_loss:0.5005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:145  d_loss:0.8056  g_loss:0.4995
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:146  d_loss:0.8065  g_loss:0.4986
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:147  d_loss:0.8073  g_loss:0.4977
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:148  d_loss:0.8081  g_loss:0.4968
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:149  d_loss:0.8089  g_loss:0.4959
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:150  d_loss:0.8098  g_loss:0.4950
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:151  d_loss:0.8107  g_loss:0.4941
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:152  d_loss:0.8115  g_loss:0.4931
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:153  d_loss:0.8123  g_loss:0.4923
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:154  d_loss:0.8131  g_loss:0.4913
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:155  d_loss:0.8140  g_loss:0.4905
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:156  d_loss:0.8147  g_loss:0.4895
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch:157  d_loss:0.8156  g_loss:0.4887
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch:158  d_loss:0.8165  g_loss:0.4878
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:159  d_loss:0.8174  g_loss:0.4869
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:160  d_loss:0.8183  g_loss:0.4860
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch:161  d_loss:0.8191  g_loss:0.4852
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:162  d_loss:0.8200  g_loss:0.4843
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:163  d_loss:0.8208  g_loss:0.4835
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:164  d_loss:0.8217  g_loss:0.4826
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:165  d_loss:0.8225  g_loss:0.4817
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:166  d_loss:0.8234  g_loss:0.4808
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:167  d_loss:0.8243  g_loss:0.4800
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:168  d_loss:0.8251  g_loss:0.4791
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:169  d_loss:0.8259  g_loss:0.4783
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:170  d_loss:0.8268  g_loss:0.4774
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:171  d_loss:0.8276  g_loss:0.4766
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:172  d_loss:0.8285  g_loss:0.4758
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:173  d_loss:0.8293  g_loss:0.4749
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:174  d_loss:0.8302  g_loss:0.4741
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:175  d_loss:0.8310  g_loss:0.4733
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:176  d_loss:0.8318  g_loss:0.4725
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:177  d_loss:0.8327  g_loss:0.4717
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:178  d_loss:0.8336  g_loss:0.4709
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:179  d_loss:0.8344  g_loss:0.4701
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:180  d_loss:0.8353  g_loss:0.4693
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch:181  d_loss:0.8361  g_loss:0.4684
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:182  d_loss:0.8370  g_loss:0.4676
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:183  d_loss:0.8378  g_loss:0.4668
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:184  d_loss:0.8387  g_loss:0.4660
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:185  d_loss:0.8395  g_loss:0.4652
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:186  d_loss:0.8404  g_loss:0.4644
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:187  d_loss:0.8412  g_loss:0.4636
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:188  d_loss:0.8421  g_loss:0.4628
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:189  d_loss:0.8430  g_loss:0.4620
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:190  d_loss:0.8438  g_loss:0.4612
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:191  d_loss:0.8447  g_loss:0.4604
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:192  d_loss:0.8455  g_loss:0.4596
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:193  d_loss:0.8464  g_loss:0.4588
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:194  d_loss:0.8472  g_loss:0.4580
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:195  d_loss:0.8480  g_loss:0.4573
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:196  d_loss:0.8489  g_loss:0.4565
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:197  d_loss:0.8497  g_loss:0.4557
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:198  d_loss:0.8504  g_loss:0.4550
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:199  d_loss:0.8513  g_loss:0.4542
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:200  d_loss:0.8521  g_loss:0.4535
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:201  d_loss:0.8529  g_loss:0.4527
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:202  d_loss:0.8538  g_loss:0.4520
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch:203  d_loss:0.8547  g_loss:0.4512
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:204  d_loss:0.8555  g_loss:0.4505
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:205  d_loss:0.8564  g_loss:0.4498
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:206  d_loss:0.8572  g_loss:0.4490
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:207  d_loss:0.8581  g_loss:0.4483
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:208  d_loss:0.8589  g_loss:0.4476
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:209  d_loss:0.8597  g_loss:0.4469
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:210  d_loss:0.8605  g_loss:0.4461
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch:211  d_loss:0.8614  g_loss:0.4453
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:212  d_loss:0.8623  g_loss:0.4446
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch:213  d_loss:0.8631  g_loss:0.4439
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch:214  d_loss:0.8640  g_loss:0.4432
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:215  d_loss:0.8648  g_loss:0.4425
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:216  d_loss:0.8657  g_loss:0.4418
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:217  d_loss:0.8665  g_loss:0.4410
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:218  d_loss:0.8674  g_loss:0.4403
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:219  d_loss:0.8682  g_loss:0.4396
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch:220  d_loss:0.8690  g_loss:0.4389
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch:221  d_loss:0.8699  g_loss:0.4383
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:222  d_loss:0.8707  g_loss:0.4375
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:223  d_loss:0.8715  g_loss:0.4369
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:224  d_loss:0.8723  g_loss:0.4362
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch:225  d_loss:0.8731  g_loss:0.4355
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:226  d_loss:0.8739  g_loss:0.4348
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:227  d_loss:0.8747  g_loss:0.4341
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:228  d_loss:0.8755  g_loss:0.4334
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:229  d_loss:0.8763  g_loss:0.4327
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:230  d_loss:0.8771  g_loss:0.4321
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:231  d_loss:0.8779  g_loss:0.4314
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:232  d_loss:0.8788  g_loss:0.4307
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:233  d_loss:0.8796  g_loss:0.4301
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:234  d_loss:0.8804  g_loss:0.4294
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:235  d_loss:0.8812  g_loss:0.4287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:236  d_loss:0.8820  g_loss:0.4280
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:237  d_loss:0.8828  g_loss:0.4274
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:238  d_loss:0.8835  g_loss:0.4268
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:239  d_loss:0.8843  g_loss:0.4261
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:240  d_loss:0.8851  g_loss:0.4255
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:241  d_loss:0.8860  g_loss:0.4248
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:242  d_loss:0.8868  g_loss:0.4242
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:243  d_loss:0.8876  g_loss:0.4236
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:244  d_loss:0.8884  g_loss:0.4230
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:245  d_loss:0.8892  g_loss:0.4223
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:246  d_loss:0.8901  g_loss:0.4217
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:247  d_loss:0.8908  g_loss:0.4211
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:248  d_loss:0.8916  g_loss:0.4205
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:249  d_loss:0.8924  g_loss:0.4199
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:250  d_loss:0.8932  g_loss:0.4193
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:251  d_loss:0.8939  g_loss:0.4187
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:252  d_loss:0.8947  g_loss:0.4181
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:253  d_loss:0.8955  g_loss:0.4175
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:254  d_loss:0.8962  g_loss:0.4169
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:255  d_loss:0.8970  g_loss:0.4163
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:256  d_loss:0.8977  g_loss:0.4156
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:257  d_loss:0.8984  g_loss:0.4150
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:258  d_loss:0.8992  g_loss:0.4144
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:259  d_loss:0.8999  g_loss:0.4138
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:260  d_loss:0.9007  g_loss:0.4132
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:261  d_loss:0.9015  g_loss:0.4126
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:262  d_loss:0.9022  g_loss:0.4120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:263  d_loss:0.9030  g_loss:0.4114
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:264  d_loss:0.9037  g_loss:0.4109
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:265  d_loss:0.9044  g_loss:0.4103
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:266  d_loss:0.9051  g_loss:0.4097
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:267  d_loss:0.9059  g_loss:0.4091
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:268  d_loss:0.9066  g_loss:0.4085
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:269  d_loss:0.9073  g_loss:0.4080
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch:270  d_loss:0.9080  g_loss:0.4074
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:271  d_loss:0.9088  g_loss:0.4068
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:272  d_loss:0.9095  g_loss:0.4063
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:273  d_loss:0.9102  g_loss:0.4057
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:274  d_loss:0.9110  g_loss:0.4051
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:275  d_loss:0.9117  g_loss:0.4046
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:276  d_loss:0.9124  g_loss:0.4040
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:277  d_loss:0.9131  g_loss:0.4035
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:278  d_loss:0.9139  g_loss:0.4029
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:279  d_loss:0.9146  g_loss:0.4024
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch:280  d_loss:0.9153  g_loss:0.4018
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:281  d_loss:0.9161  g_loss:0.4013
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:282  d_loss:0.9168  g_loss:0.4007
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:283  d_loss:0.9175  g_loss:0.4002
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:284  d_loss:0.9182  g_loss:0.3997
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:285  d_loss:0.9189  g_loss:0.3991
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:286  d_loss:0.9196  g_loss:0.3986
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:287  d_loss:0.9203  g_loss:0.3980
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:288  d_loss:0.9209  g_loss:0.3975
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:289  d_loss:0.9217  g_loss:0.3970
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch:290  d_loss:0.9224  g_loss:0.3965
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:291  d_loss:0.9231  g_loss:0.3960
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:292  d_loss:0.9238  g_loss:0.3955
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:293  d_loss:0.9245  g_loss:0.3949
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:294  d_loss:0.9252  g_loss:0.3944
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:295  d_loss:0.9259  g_loss:0.3939
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch:296  d_loss:0.9265  g_loss:0.3934
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:297  d_loss:0.9272  g_loss:0.3929
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:298  d_loss:0.9279  g_loss:0.3924
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:299  d_loss:0.9286  g_loss:0.3919
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:300  d_loss:0.9292  g_loss:0.3914
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch:301  d_loss:0.9299  g_loss:0.3909
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:302  d_loss:0.9305  g_loss:0.3904
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:303  d_loss:0.9312  g_loss:0.3899
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:304  d_loss:0.9318  g_loss:0.3894
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:305  d_loss:0.9325  g_loss:0.3889
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:306  d_loss:0.9331  g_loss:0.3884
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:307  d_loss:0.9338  g_loss:0.3879
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:308  d_loss:0.9345  g_loss:0.3874
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:309  d_loss:0.9352  g_loss:0.3869
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:310  d_loss:0.9358  g_loss:0.3864
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:311  d_loss:0.9364  g_loss:0.3859
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:312  d_loss:0.9371  g_loss:0.3855
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:313  d_loss:0.9377  g_loss:0.3850
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:314  d_loss:0.9384  g_loss:0.3845
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:315  d_loss:0.9390  g_loss:0.3840
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:316  d_loss:0.9397  g_loss:0.3835
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:317  d_loss:0.9403  g_loss:0.3831
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:318  d_loss:0.9410  g_loss:0.3826
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch:319  d_loss:0.9416  g_loss:0.3821
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:320  d_loss:0.9423  g_loss:0.3817
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:321  d_loss:0.9429  g_loss:0.3812
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:322  d_loss:0.9435  g_loss:0.3807
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:323  d_loss:0.9442  g_loss:0.3803
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:324  d_loss:0.9448  g_loss:0.3798
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:325  d_loss:0.9455  g_loss:0.3794
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:326  d_loss:0.9461  g_loss:0.3789
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:327  d_loss:0.9467  g_loss:0.3784
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:328  d_loss:0.9474  g_loss:0.3780
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:329  d_loss:0.9480  g_loss:0.3775
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:330  d_loss:0.9486  g_loss:0.3771
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch:331  d_loss:0.9493  g_loss:0.3767
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:332  d_loss:0.9499  g_loss:0.3762
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:333  d_loss:0.9505  g_loss:0.3758
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:334  d_loss:0.9511  g_loss:0.3753
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:335  d_loss:0.9517  g_loss:0.3749
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:336  d_loss:0.9523  g_loss:0.3744
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:337  d_loss:0.9529  g_loss:0.3740
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:338  d_loss:0.9535  g_loss:0.3736
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:339  d_loss:0.9541  g_loss:0.3731
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:340  d_loss:0.9547  g_loss:0.3727
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:341  d_loss:0.9554  g_loss:0.3723
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:342  d_loss:0.9560  g_loss:0.3718
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:343  d_loss:0.9566  g_loss:0.3714
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:344  d_loss:0.9572  g_loss:0.3710
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:345  d_loss:0.9578  g_loss:0.3706
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:346  d_loss:0.9584  g_loss:0.3702
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:347  d_loss:0.9589  g_loss:0.3697
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:348  d_loss:0.9595  g_loss:0.3693
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:349  d_loss:0.9601  g_loss:0.3689
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:350  d_loss:0.9606  g_loss:0.3685
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:351  d_loss:0.9612  g_loss:0.3681
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:352  d_loss:0.9618  g_loss:0.3677
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:353  d_loss:0.9624  g_loss:0.3673
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:354  d_loss:0.9630  g_loss:0.3669
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:355  d_loss:0.9636  g_loss:0.3664
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:356  d_loss:0.9641  g_loss:0.3660
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:357  d_loss:0.9647  g_loss:0.3656
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:358  d_loss:0.9653  g_loss:0.3652
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:359  d_loss:0.9658  g_loss:0.3648
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:360  d_loss:0.9664  g_loss:0.3644
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:361  d_loss:0.9669  g_loss:0.3640
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:362  d_loss:0.9675  g_loss:0.3636
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:363  d_loss:0.9681  g_loss:0.3632
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:364  d_loss:0.9686  g_loss:0.3628
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:365  d_loss:0.9692  g_loss:0.3624
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:366  d_loss:0.9698  g_loss:0.3620
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:367  d_loss:0.9703  g_loss:0.3616
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:368  d_loss:0.9709  g_loss:0.3613
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:369  d_loss:0.9714  g_loss:0.3609
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:370  d_loss:0.9720  g_loss:0.3605
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:371  d_loss:0.9726  g_loss:0.3601
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:372  d_loss:0.9732  g_loss:0.3597
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:373  d_loss:0.9737  g_loss:0.3593
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:374  d_loss:0.9743  g_loss:0.3589
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:375  d_loss:0.9748  g_loss:0.3586
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:376  d_loss:0.9753  g_loss:0.3582
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:377  d_loss:0.9758  g_loss:0.3578
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:378  d_loss:0.9764  g_loss:0.3574
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:379  d_loss:0.9770  g_loss:0.3570
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:380  d_loss:0.9775  g_loss:0.3567
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:381  d_loss:0.9780  g_loss:0.3563
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch:382  d_loss:0.9786  g_loss:0.3559
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:383  d_loss:0.9791  g_loss:0.3556
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:384  d_loss:0.9796  g_loss:0.3552
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:385  d_loss:0.9801  g_loss:0.3548
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:386  d_loss:0.9806  g_loss:0.3545
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:387  d_loss:0.9812  g_loss:0.3541
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:388  d_loss:0.9817  g_loss:0.3538
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:389  d_loss:0.9822  g_loss:0.3534
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:390  d_loss:0.9827  g_loss:0.3530
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:391  d_loss:0.9832  g_loss:0.3527
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:392  d_loss:0.9837  g_loss:0.3523
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:393  d_loss:0.9843  g_loss:0.3519
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:394  d_loss:0.9848  g_loss:0.3516
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:395  d_loss:0.9853  g_loss:0.3512
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:396  d_loss:0.9858  g_loss:0.3509
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:397  d_loss:0.9863  g_loss:0.3505
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:398  d_loss:0.9868  g_loss:0.3502
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:399  d_loss:0.9874  g_loss:0.3498
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:400  d_loss:0.9879  g_loss:0.3495
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:401  d_loss:0.9884  g_loss:0.3492
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:402  d_loss:0.9889  g_loss:0.3488
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:403  d_loss:0.9894  g_loss:0.3485
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:404  d_loss:0.9899  g_loss:0.3481
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:405  d_loss:0.9904  g_loss:0.3478
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:406  d_loss:0.9909  g_loss:0.3474
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:407  d_loss:0.9913  g_loss:0.3471
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:408  d_loss:0.9918  g_loss:0.3468
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:409  d_loss:0.9923  g_loss:0.3464
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:410  d_loss:0.9928  g_loss:0.3461
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:411  d_loss:0.9933  g_loss:0.3458
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch:412  d_loss:0.9938  g_loss:0.3454
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:413  d_loss:0.9943  g_loss:0.3451
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:414  d_loss:0.9948  g_loss:0.3448
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:415  d_loss:0.9953  g_loss:0.3444
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:416  d_loss:0.9958  g_loss:0.3441
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:417  d_loss:0.9963  g_loss:0.3438
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:418  d_loss:0.9968  g_loss:0.3435
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch:419  d_loss:0.9973  g_loss:0.3431
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch:420  d_loss:0.9977  g_loss:0.3428
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:421  d_loss:0.9982  g_loss:0.3425
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:422  d_loss:0.9987  g_loss:0.3422
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:423  d_loss:0.9992  g_loss:0.3418
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:424  d_loss:0.9997  g_loss:0.3415
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch:425  d_loss:1.0002  g_loss:0.3412
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:426  d_loss:1.0006  g_loss:0.3409
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:427  d_loss:1.0011  g_loss:0.3405
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:428  d_loss:1.0015  g_loss:0.3402
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:429  d_loss:1.0020  g_loss:0.3399
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:430  d_loss:1.0025  g_loss:0.3396
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:431  d_loss:1.0029  g_loss:0.3393
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:432  d_loss:1.0034  g_loss:0.3390
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:433  d_loss:1.0039  g_loss:0.3387
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch:434  d_loss:1.0044  g_loss:0.3384
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:435  d_loss:1.0049  g_loss:0.3380
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:436  d_loss:1.0053  g_loss:0.3377
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:437  d_loss:1.0058  g_loss:0.3374
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:438  d_loss:1.0063  g_loss:0.3371
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:439  d_loss:1.0067  g_loss:0.3368
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:440  d_loss:1.0072  g_loss:0.3365
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:441  d_loss:1.0076  g_loss:0.3362
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:442  d_loss:1.0081  g_loss:0.3359
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:443  d_loss:1.0086  g_loss:0.3356
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:444  d_loss:1.0090  g_loss:0.3353
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:445  d_loss:1.0094  g_loss:0.3350
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:446  d_loss:1.0099  g_loss:0.3347
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:447  d_loss:1.0103  g_loss:0.3344
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:448  d_loss:1.0107  g_loss:0.3341
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:449  d_loss:1.0112  g_loss:0.3338
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch:450  d_loss:1.0116  g_loss:0.3335
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:451  d_loss:1.0120  g_loss:0.3332
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:452  d_loss:1.0124  g_loss:0.3329
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:453  d_loss:1.0128  g_loss:0.3326
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:454  d_loss:1.0133  g_loss:0.3323
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:455  d_loss:1.0137  g_loss:0.3320
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:456  d_loss:1.0141  g_loss:0.3317
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:457  d_loss:1.0146  g_loss:0.3315
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:458  d_loss:1.0150  g_loss:0.3312
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:459  d_loss:1.0154  g_loss:0.3309
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:460  d_loss:1.0158  g_loss:0.3306
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:461  d_loss:1.0163  g_loss:0.3303
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:462  d_loss:1.0167  g_loss:0.3300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch:463  d_loss:1.0171  g_loss:0.3298
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:464  d_loss:1.0175  g_loss:0.3295
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch:465  d_loss:1.0179  g_loss:0.3292
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:466  d_loss:1.0183  g_loss:0.3289
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:467  d_loss:1.0187  g_loss:0.3286
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:468  d_loss:1.0191  g_loss:0.3283
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:469  d_loss:1.0196  g_loss:0.3281
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:470  d_loss:1.0200  g_loss:0.3278
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:471  d_loss:1.0204  g_loss:0.3275
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:472  d_loss:1.0208  g_loss:0.3272
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:473  d_loss:1.0212  g_loss:0.3270
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:474  d_loss:1.0216  g_loss:0.3267
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:475  d_loss:1.0220  g_loss:0.3264
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:476  d_loss:1.0224  g_loss:0.3261
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:477  d_loss:1.0228  g_loss:0.3259
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:478  d_loss:1.0232  g_loss:0.3256
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:479  d_loss:1.0236  g_loss:0.3253
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch:480  d_loss:1.0240  g_loss:0.3250
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:481  d_loss:1.0244  g_loss:0.3248
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:482  d_loss:1.0248  g_loss:0.3245
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:483  d_loss:1.0252  g_loss:0.3242
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:484  d_loss:1.0256  g_loss:0.3240
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:485  d_loss:1.0260  g_loss:0.3237
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:486  d_loss:1.0264  g_loss:0.3235
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:487  d_loss:1.0268  g_loss:0.3232
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:488  d_loss:1.0272  g_loss:0.3229
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:489  d_loss:1.0276  g_loss:0.3227
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:490  d_loss:1.0280  g_loss:0.3224
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:491  d_loss:1.0284  g_loss:0.3222
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:492  d_loss:1.0288  g_loss:0.3219
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:493  d_loss:1.0292  g_loss:0.3216
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:494  d_loss:1.0296  g_loss:0.3214
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch:495  d_loss:1.0300  g_loss:0.3211
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:496  d_loss:1.0303  g_loss:0.3209
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:497  d_loss:1.0307  g_loss:0.3206
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:498  d_loss:1.0311  g_loss:0.3204
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:499  d_loss:1.0316  g_loss:0.3201
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:500  d_loss:1.0319  g_loss:0.3198
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:501  d_loss:1.0323  g_loss:0.3196
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:502  d_loss:1.0327  g_loss:0.3193
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:503  d_loss:1.0331  g_loss:0.3191
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:504  d_loss:1.0335  g_loss:0.3188
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:505  d_loss:1.0338  g_loss:0.3186
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:506  d_loss:1.0342  g_loss:0.3184
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:507  d_loss:1.0346  g_loss:0.3181
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:508  d_loss:1.0350  g_loss:0.3179
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:509  d_loss:1.0354  g_loss:0.3176
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:510  d_loss:1.0358  g_loss:0.3174
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:511  d_loss:1.0361  g_loss:0.3171
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:512  d_loss:1.0365  g_loss:0.3169
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:513  d_loss:1.0369  g_loss:0.3166
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:514  d_loss:1.0372  g_loss:0.3164
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:515  d_loss:1.0376  g_loss:0.3162
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:516  d_loss:1.0380  g_loss:0.3159
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:517  d_loss:1.0383  g_loss:0.3157
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:518  d_loss:1.0387  g_loss:0.3154
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:519  d_loss:1.0390  g_loss:0.3152
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:520  d_loss:1.0394  g_loss:0.3149
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:521  d_loss:1.0397  g_loss:0.3147
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:522  d_loss:1.0401  g_loss:0.3145
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:523  d_loss:1.0405  g_loss:0.3142
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch:524  d_loss:1.0408  g_loss:0.3140
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:525  d_loss:1.0411  g_loss:0.3138
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:526  d_loss:1.0415  g_loss:0.3135
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:527  d_loss:1.0419  g_loss:0.3133
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:528  d_loss:1.0422  g_loss:0.3131
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch:529  d_loss:1.0426  g_loss:0.3128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:530  d_loss:1.0429  g_loss:0.3126
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:531  d_loss:1.0432  g_loss:0.3124
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:532  d_loss:1.0436  g_loss:0.3122
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch:533  d_loss:1.0440  g_loss:0.3119
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:534  d_loss:1.0443  g_loss:0.3117
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:535  d_loss:1.0447  g_loss:0.3115
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:536  d_loss:1.0450  g_loss:0.3113
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:537  d_loss:1.0454  g_loss:0.3110
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch:538  d_loss:1.0457  g_loss:0.3108
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:539  d_loss:1.0460  g_loss:0.3106
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:540  d_loss:1.0464  g_loss:0.3104
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:541  d_loss:1.0467  g_loss:0.3101
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:542  d_loss:1.0470  g_loss:0.3099
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:543  d_loss:1.0474  g_loss:0.3097
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:544  d_loss:1.0477  g_loss:0.3095
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:545  d_loss:1.0481  g_loss:0.3092
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:546  d_loss:1.0484  g_loss:0.3090
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:547  d_loss:1.0487  g_loss:0.3088
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:548  d_loss:1.0491  g_loss:0.3086
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:549  d_loss:1.0494  g_loss:0.3084
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:550  d_loss:1.0498  g_loss:0.3081
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:551  d_loss:1.0501  g_loss:0.3079
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:552  d_loss:1.0505  g_loss:0.3077
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:553  d_loss:1.0508  g_loss:0.3075
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:554  d_loss:1.0511  g_loss:0.3073
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:555  d_loss:1.0514  g_loss:0.3070
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:556  d_loss:1.0518  g_loss:0.3068
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:557  d_loss:1.0521  g_loss:0.3066
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:558  d_loss:1.0524  g_loss:0.3064
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:559  d_loss:1.0527  g_loss:0.3062
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:560  d_loss:1.0531  g_loss:0.3060
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:561  d_loss:1.0534  g_loss:0.3058
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:562  d_loss:1.0537  g_loss:0.3056
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:563  d_loss:1.0540  g_loss:0.3054
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:564  d_loss:1.0544  g_loss:0.3051
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:565  d_loss:1.0547  g_loss:0.3049
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:566  d_loss:1.0550  g_loss:0.3047
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:567  d_loss:1.0553  g_loss:0.3045
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:568  d_loss:1.0557  g_loss:0.3043
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:569  d_loss:1.0560  g_loss:0.3041
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:570  d_loss:1.0563  g_loss:0.3039
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:571  d_loss:1.0566  g_loss:0.3037
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:572  d_loss:1.0569  g_loss:0.3035
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:573  d_loss:1.0573  g_loss:0.3033
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:574  d_loss:1.0576  g_loss:0.3031
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:575  d_loss:1.0579  g_loss:0.3029
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:576  d_loss:1.0583  g_loss:0.3027
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:577  d_loss:1.0586  g_loss:0.3025
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:578  d_loss:1.0589  g_loss:0.3023
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:579  d_loss:1.0592  g_loss:0.3021
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:580  d_loss:1.0595  g_loss:0.3019
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:581  d_loss:1.0598  g_loss:0.3017
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:582  d_loss:1.0601  g_loss:0.3015
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:583  d_loss:1.0604  g_loss:0.3013
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:584  d_loss:1.0607  g_loss:0.3011
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:585  d_loss:1.0610  g_loss:0.3009
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:586  d_loss:1.0614  g_loss:0.3007
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:587  d_loss:1.0617  g_loss:0.3005
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:588  d_loss:1.0620  g_loss:0.3003
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:589  d_loss:1.0622  g_loss:0.3001
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:590  d_loss:1.0625  g_loss:0.2999
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:591  d_loss:1.0628  g_loss:0.2997
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:592  d_loss:1.0631  g_loss:0.2996
# ...
# epoch:1799  d_loss:1.2085  g_loss:0.2124
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch:1800  d_loss:1.2086  g_loss:0.2124
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch:1801  d_loss:1.2086  g_loss:0.2123
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1802  d_loss:1.2087  g_loss:0.2123
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:1803  d_loss:1.2087  g_loss:0.2123
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1804  d_loss:1.2088  g_loss:0.2123
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1805  d_loss:1.2088  g_loss:0.2122
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch:1806  d_loss:1.2089  g_loss:0.2122
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:1807  d_loss:1.2089  g_loss:0.2122
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1808  d_loss:1.2090  g_loss:0.2122
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1809  d_loss:1.2090  g_loss:0.2121
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1810  d_loss:1.2090  g_loss:0.2121
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:1811  d_loss:1.2091  g_loss:0.2121
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1812  d_loss:1.2091  g_loss:0.2121
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1813  d_loss:1.2092  g_loss:0.2120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1814  d_loss:1.2092  g_loss:0.2120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1815  d_loss:1.2093  g_loss:0.2120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:1816  d_loss:1.2093  g_loss:0.2120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1817  d_loss:1.2094  g_loss:0.2119
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:1818  d_loss:1.2094  g_loss:0.2119
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:1819  d_loss:1.2095  g_loss:0.2119
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1820  d_loss:1.2095  g_loss:0.2118
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1821  d_loss:1.2096  g_loss:0.2118
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:1822  d_loss:1.2096  g_loss:0.2118
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:1823  d_loss:1.2096  g_loss:0.2118
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1824  d_loss:1.2097  g_loss:0.2117
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1825  d_loss:1.2097  g_loss:0.2117
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1826  d_loss:1.2098  g_loss:0.2117
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:1827  d_loss:1.2098  g_loss:0.2117
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:1828  d_loss:1.2099  g_loss:0.2116
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1829  d_loss:1.2099  g_loss:0.2116
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:1830  d_loss:1.2100  g_loss:0.2116
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:1831  d_loss:1.2100  g_loss:0.2116
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1832  d_loss:1.2101  g_loss:0.2115
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1833  d_loss:1.2101  g_loss:0.2115
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1834  d_loss:1.2101  g_loss:0.2115
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1835  d_loss:1.2102  g_loss:0.2115
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1836  d_loss:1.2102  g_loss:0.2114
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:1837  d_loss:1.2103  g_loss:0.2114
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:1838  d_loss:1.2103  g_loss:0.2114
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1839  d_loss:1.2104  g_loss:0.2114
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:1840  d_loss:1.2104  g_loss:0.2113
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1841  d_loss:1.2104  g_loss:0.2113
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1842  d_loss:1.2105  g_loss:0.2113
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1843  d_loss:1.2105  g_loss:0.2113
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch:1844  d_loss:1.2106  g_loss:0.2112
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1845  d_loss:1.2106  g_loss:0.2112
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1846  d_loss:1.2107  g_loss:0.2112
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1847  d_loss:1.2107  g_loss:0.2112
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1848  d_loss:1.2108  g_loss:0.2111
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:1849  d_loss:1.2108  g_loss:0.2111
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1850  d_loss:1.2109  g_loss:0.2111
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1851  d_loss:1.2109  g_loss:0.2111
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1852  d_loss:1.2109  g_loss:0.2110
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1853  d_loss:1.2110  g_loss:0.2110
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1854  d_loss:1.2110  g_loss:0.2110
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1855  d_loss:1.2111  g_loss:0.2110
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1856  d_loss:1.2111  g_loss:0.2109
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1857  d_loss:1.2112  g_loss:0.2109
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1858  d_loss:1.2112  g_loss:0.2109
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1859  d_loss:1.2113  g_loss:0.2109
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:1860  d_loss:1.2113  g_loss:0.2108
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1861  d_loss:1.2113  g_loss:0.2108
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1862  d_loss:1.2114  g_loss:0.2108
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1863  d_loss:1.2114  g_loss:0.2108
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:1864  d_loss:1.2115  g_loss:0.2107
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:1865  d_loss:1.2115  g_loss:0.2107
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1866  d_loss:1.2115  g_loss:0.2107
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1867  d_loss:1.2116  g_loss:0.2107
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1868  d_loss:1.2116  g_loss:0.2106
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1869  d_loss:1.2117  g_loss:0.2106
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1870  d_loss:1.2117  g_loss:0.2106
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1871  d_loss:1.2118  g_loss:0.2106
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1872  d_loss:1.2118  g_loss:0.2105
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1873  d_loss:1.2118  g_loss:0.2105
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1874  d_loss:1.2119  g_loss:0.2105
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch:1875  d_loss:1.2119  g_loss:0.2105
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:1876  d_loss:1.2120  g_loss:0.2104
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1877  d_loss:1.2120  g_loss:0.2104
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:1878  d_loss:1.2120  g_loss:0.2104
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1879  d_loss:1.2121  g_loss:0.2104
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch:1880  d_loss:1.2121  g_loss:0.2103
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1881  d_loss:1.2122  g_loss:0.2103
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1882  d_loss:1.2122  g_loss:0.2103
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1883  d_loss:1.2123  g_loss:0.2103
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1884  d_loss:1.2123  g_loss:0.2103
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1885  d_loss:1.2123  g_loss:0.2102
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1886  d_loss:1.2124  g_loss:0.2102
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch:1887  d_loss:1.2124  g_loss:0.2102
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1888  d_loss:1.2125  g_loss:0.2102
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1889  d_loss:1.2125  g_loss:0.2101
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:1890  d_loss:1.2126  g_loss:0.2101
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1891  d_loss:1.2126  g_loss:0.2101
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1892  d_loss:1.2126  g_loss:0.2101
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:1893  d_loss:1.2127  g_loss:0.2100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1894  d_loss:1.2127  g_loss:0.2100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1895  d_loss:1.2128  g_loss:0.2100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1896  d_loss:1.2128  g_loss:0.2100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1897  d_loss:1.2128  g_loss:0.2099
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1898  d_loss:1.2129  g_loss:0.2099
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1899  d_loss:1.2129  g_loss:0.2099
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:1900  d_loss:1.2130  g_loss:0.2099
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1901  d_loss:1.2130  g_loss:0.2099
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1902  d_loss:1.2130  g_loss:0.2098
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1903  d_loss:1.2131  g_loss:0.2098
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1904  d_loss:1.2131  g_loss:0.2098
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch:1905  d_loss:1.2132  g_loss:0.2098
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1906  d_loss:1.2132  g_loss:0.2097
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch:1907  d_loss:1.2132  g_loss:0.2097
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1908  d_loss:1.2133  g_loss:0.2097
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1909  d_loss:1.2133  g_loss:0.2097
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:1910  d_loss:1.2133  g_loss:0.2096
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1911  d_loss:1.2134  g_loss:0.2096
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1912  d_loss:1.2134  g_loss:0.2096
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:1913  d_loss:1.2135  g_loss:0.2096
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:1914  d_loss:1.2135  g_loss:0.2095
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1915  d_loss:1.2135  g_loss:0.2095
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1916  d_loss:1.2136  g_loss:0.2095
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1917  d_loss:1.2136  g_loss:0.2095
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1918  d_loss:1.2137  g_loss:0.2095
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1919  d_loss:1.2137  g_loss:0.2094
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1920  d_loss:1.2138  g_loss:0.2094
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:1921  d_loss:1.2138  g_loss:0.2094
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1922  d_loss:1.2138  g_loss:0.2094
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1923  d_loss:1.2139  g_loss:0.2093
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:1924  d_loss:1.2139  g_loss:0.2093
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:1925  d_loss:1.2140  g_loss:0.2093
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1926  d_loss:1.2140  g_loss:0.2093
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1927  d_loss:1.2141  g_loss:0.2092
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1928  d_loss:1.2141  g_loss:0.2092
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1929  d_loss:1.2141  g_loss:0.2092
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# epoch:1930  d_loss:1.2142  g_loss:0.2092
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1931  d_loss:1.2142  g_loss:0.2091
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1932  d_loss:1.2143  g_loss:0.2091
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1933  d_loss:1.2143  g_loss:0.2091
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1934  d_loss:1.2143  g_loss:0.2091
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch:1935  d_loss:1.2144  g_loss:0.2091
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch:1936  d_loss:1.2144  g_loss:0.2090
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:1937  d_loss:1.2145  g_loss:0.2090
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1938  d_loss:1.2145  g_loss:0.2090
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1939  d_loss:1.2145  g_loss:0.2090
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:1940  d_loss:1.2146  g_loss:0.2089
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch:1941  d_loss:1.2146  g_loss:0.2089
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1942  d_loss:1.2147  g_loss:0.2089
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1943  d_loss:1.2147  g_loss:0.2089
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1944  d_loss:1.2147  g_loss:0.2088
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch:1945  d_loss:1.2148  g_loss:0.2088
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch:1946  d_loss:1.2148  g_loss:0.2088
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# epoch:1947  d_loss:1.2149  g_loss:0.2088
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1948  d_loss:1.2149  g_loss:0.2088
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:1949  d_loss:1.2149  g_loss:0.2087
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1950  d_loss:1.2150  g_loss:0.2087
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1951  d_loss:1.2150  g_loss:0.2087
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# epoch:1952  d_loss:1.2151  g_loss:0.2087
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1953  d_loss:1.2151  g_loss:0.2086
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1954  d_loss:1.2152  g_loss:0.2086
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1955  d_loss:1.2152  g_loss:0.2086
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1956  d_loss:1.2152  g_loss:0.2086
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1957  d_loss:1.2153  g_loss:0.2086
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1958  d_loss:1.2153  g_loss:0.2085
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1959  d_loss:1.2153  g_loss:0.2085
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1960  d_loss:1.2154  g_loss:0.2085
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch:1961  d_loss:1.2154  g_loss:0.2085
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1962  d_loss:1.2155  g_loss:0.2084
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# epoch:1963  d_loss:1.2155  g_loss:0.2084
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1964  d_loss:1.2155  g_loss:0.2084
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:1965  d_loss:1.2156  g_loss:0.2084
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:1966  d_loss:1.2156  g_loss:0.2084
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1967  d_loss:1.2156  g_loss:0.2083
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# epoch:1968  d_loss:1.2157  g_loss:0.2083
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1969  d_loss:1.2157  g_loss:0.2083
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1970  d_loss:1.2158  g_loss:0.2083
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1971  d_loss:1.2158  g_loss:0.2082
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1972  d_loss:1.2158  g_loss:0.2082
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1973  d_loss:1.2159  g_loss:0.2082
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1974  d_loss:1.2159  g_loss:0.2082
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# epoch:1975  d_loss:1.2160  g_loss:0.2082
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:1976  d_loss:1.2160  g_loss:0.2081
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1977  d_loss:1.2161  g_loss:0.2081
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1978  d_loss:1.2161  g_loss:0.2081
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1979  d_loss:1.2161  g_loss:0.2081
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:1980  d_loss:1.2162  g_loss:0.2080
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1981  d_loss:1.2162  g_loss:0.2080
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1982  d_loss:1.2162  g_loss:0.2080
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:1983  d_loss:1.2163  g_loss:0.2080
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1984  d_loss:1.2163  g_loss:0.2080
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1985  d_loss:1.2164  g_loss:0.2079
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# epoch:1986  d_loss:1.2164  g_loss:0.2079
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1987  d_loss:1.2165  g_loss:0.2079
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:1988  d_loss:1.2165  g_loss:0.2079
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1989  d_loss:1.2165  g_loss:0.2078
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# epoch:1990  d_loss:1.2166  g_loss:0.2078
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1991  d_loss:1.2166  g_loss:0.2078
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1992  d_loss:1.2166  g_loss:0.2078
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1993  d_loss:1.2167  g_loss:0.2078
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1994  d_loss:1.2167  g_loss:0.2077
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1995  d_loss:1.2167  g_loss:0.2077
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:1996  d_loss:1.2168  g_loss:0.2077
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# epoch:1997  d_loss:1.2168  g_loss:0.2077
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1998  d_loss:1.2168  g_loss:0.2076
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# epoch:1999  d_loss:1.2169  g_loss:0.2076
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# epoch:2000  d_loss:1.2169  g_loss:0.2076
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %% [markdown]
# ## 4. 이미지의 특징을 추출하는 오토인코더
# - 오토인코더도 이미지를 생성해내는 GAN 같은 알고리즘임
# - Gan과 다른점은, Gan은 완전 새로운 이미지를 만들어내고, 오터인코더는 기존의 데이터에서 특징을 잘 추출해서 새로운 이미지를 만드는 방식이라는것임

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Reshape
import matplotlib.pyplot as plt
import numpy as np

(X_train, _), (X_test, _) = mnist.load_data()
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32') / 255
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32') / 255

# 생성자 모델
autoencoder = Sequential()

# 인코딩 부분
autoencoder.add(Conv2D(16, kernel_size=3, padding='same', input_shape=(28,28,1), activation='relu'))
autoencoder.add(MaxPooling2D(pool_size=2, padding='same'))
autoencoder.add(Conv2D(8, kernel_size=3, activation='relu', padding='same'))
autoencoder.add(MaxPooling2D(pool_size=2, padding='same'))
autoencoder.add(Conv2D(8, kernel_size=3, strides=2, padding='same', activation='relu'))

# 디코딩 부분
autoencoder.add(Conv2D(8, kernel_size=3, padding='same', activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(8, kernel_size=3, padding='same', activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(16, kernel_size=3, activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(1, kernel_size=3, padding='same', activation='sigmoid'))

# 전체 구조를 확인해 봅니다.
autoencoder.summary()
# Out:
# c:\Users\window11\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_8 (Conv2D)               │ (None, 28, 28, 16)     │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 14, 14, 8)      │         1,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 7, 8)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 4, 4, 8)        │           584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 4, 4, 8)        │           584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_4 (UpSampling2D)  │ (None, 8, 8, 8)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_12 (Conv2D)              │ (None, 8, 8, 8)        │           584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_5 (UpSampling2D)  │ (None, 16, 16, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_13 (Conv2D)              │ (None, 14, 14, 16)     │         1,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_6 (UpSampling2D)  │ (None, 28, 28, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 28, 28, 1)      │           145 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,385 (17.13 KB)
#  Trainable params: 4,385 (17.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# 컴파일 및 학습을 하는 부분입니다.
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
autoencoder.fit(X_train, X_train, epochs=50, batch_size=128, validation_data=(X_test, X_test))

# 학습된 결과를 출력하는 부분입니다.
random_test = np.random.randint(X_test.shape[0], size=5)  # 테스트할 이미지를 랜덤하게 불러옴
ae_imgs = autoencoder.predict(X_test)                     # 앞서 만든 오토인코더 모델에 넣음

# 출력될 이미지의 크기
plt.figure(figsize=(7, 2))                        

for i, image_idx in enumerate(random_test):       
   ax = plt.subplot(2, 7, i + 1) 
   plt.imshow(X_test[image_idx].reshape(28, 28))  
   ax.axis('off')
   ax = plt.subplot(2, 7, 7 + i +1)
   plt.imshow(ae_imgs[image_idx].reshape(28, 28)) 
   ax.axis('off')
plt.show()
# Out:
# Epoch 1/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.3023 - val_loss: 0.1342
# Epoch 2/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1293 - val_loss: 0.1167
# Epoch 3/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1160 - val_loss: 0.1094
# Epoch 4/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1099 - val_loss: 0.1053
# Epoch 5/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1058 - val_loss: 0.1023
# Epoch 6/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1029 - val_loss: 0.1004
# Epoch 7/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.1011 - val_loss: 0.0983
# Epoch 8/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0993 - val_loss: 0.0970
# Epoch 9/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0979 - val_loss: 0.0959
# Epoch 10/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0969 - val_loss: 0.0951
# Epoch 11/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0960 - val_loss: 0.0939
# Epoch 12/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0951 - val_loss: 0.0932
# Epoch 13/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0942 - val_loss: 0.0927
# Epoch 14/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0934 - val_loss: 0.0919
# Epoch 15/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0929 - val_loss: 0.0914
# Epoch 16/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0920 - val_loss: 0.0908
# Epoch 17/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0913 - val_loss: 0.0903
# Epoch 18/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0911 - val_loss: 0.0903
# Epoch 19/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0904 - val_loss: 0.0890
# Epoch 20/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0899 - val_loss: 0.0892
# Epoch 21/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0895 - val_loss: 0.0882
# Epoch 22/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0892 - val_loss: 0.0879
# Epoch 23/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0886 - val_loss: 0.0875
# Epoch 24/50
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0884 - val_loss: 0.0872
# Epoch 25/50
# 458/469 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0882
